# %%
# !pip install pyspark==3.5.2

# %%
import os
os.environ["JAVA_HOME"] = r"C:\Program Files\Java\jdk-23"

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, current_date, lit, rand, current_timestamp
from datetime import datetime, timedelta
import random

def create_spark_session():
    # Windows mutlak path'leri
    jar_path = r"C:\Users\oomer\iceberg-minio-tiering\jars"
    jars = [
        f"{jar_path}\\iceberg-spark-runtime-3.5_2.12-1.5.2.jar",
        f"{jar_path}\\aws-java-sdk-bundle-1.12.262.jar",
        f"{jar_path}\\hadoop-aws-3.3.4.jar"
    ]
    
    builder = SparkSession.builder \
        .appName("Iceberg Data Ingestion") \
        .master("local[*]") \
        .config("spark.driver.port", "4040") \
        .config("spark.driver.host", "0.0.0.0") \
        .config("spark.sql.catalog.iceberg", "org.apache.iceberg.spark.SparkCatalog") \
        .config("spark.sql.catalog.iceberg.type", "hadoop") \
        .config("spark.sql.catalog.iceberg.warehouse", "s3a://iceberg-warehouse/") \
        .config("spark.hadoop.fs.s3a.endpoint", "http://localhost:9000") \
        .config("spark.hadoop.fs.s3a.access.key", "minioadmin") \
        .config("spark.hadoop.fs.s3a.secret.key", "minioadmin") \
        .config("spark.hadoop.fs.s3a.path.style.access", "true") \
        .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false") \
        .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
        .config("spark.hadoop.fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider") \
        .config("spark.hadoop.fs.s3a.connection.maximum", "100") \
        .config("spark.hadoop.fs.s3a.fast.upload", "true") \
        .config("spark.hadoop.fs.s3a.multipart.size", "104857600") \
        .config("spark.hadoop.fs.s3a.threads.max", "20") \
        .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
        .config("spark.sql.defaultCatalog", "iceberg") \
        .config("spark.sql.iceberg.format-version", "2") \
        .config("spark.sql.iceberg.compression-codec", "zstd") \
        .config("spark.sql.iceberg.compression-level", "3") \
        .config("spark.executor.memory", "2g") \
        .config("spark.driver.memory", "2g") \
        .config("spark.jars", ",".join(jars))
        
    return builder.getOrCreate()

# %%
spark = create_spark_session()
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 spark = create_spark_session()
#
# Cell In[20], line 43, in create_spark_session()
#       9 jars = [
#      10     f"{jar_path}\\iceberg-spark-runtime-3.5_2.12-1.5.2.jar",
#      11     f"{jar_path}\\aws-java-sdk-bundle-1.12.262.jar",
#      12     f"{jar_path}\\hadoop-aws-3.3.4.jar"
#      13 ]
#      15 builder = SparkSession.builder \
#      16     .appName("Iceberg Data Ingestion") \
#      17     .master("local[*]") \
#    (...)     40     .config("spark.driver.memory", "2g") \
#      41     .config("spark.jars", ",".join(jars))
# ---> 43 return builder.getOrCreate()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pyspark\sql\session.py:556, in SparkSession.Builder.getOrCreate(self)
#     554     sparkConf.set(key, value)
#     555 # This SparkContext may be an existing one.
# ...

# %%
spark.sql("show catalogs")
